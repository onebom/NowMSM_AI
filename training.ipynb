# %% [markdown]
# <a href="https://colab.research.google.com/github/onebom/NowMSM_AI/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Setup**

# %%
# %tensorflow_version 2.x
# TPU 사용
import tensorflow as tf
# import os

# resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

# tf.config.experimental_connect_to_cluster(resolver)
# tf.tpu.experimental.initialize_tpu_system(resolver)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# strategy = tf.distribute.TPUStrategy(resolver)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import collections

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Dropout, Flatten, Activation
from tensorflow.keras.layers import BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import HeNormal

# %% [markdown]
# # **Load data**

# %%
# dataset is saved in my google drive
# %cp -av "/content/gdrive/MyDrive/loopQ/project" "/content"
# %cd /content/project/

# %%
def load_data(data_file):
    print('Loading data ...')
    with open(data_file, 'rb') as f:
        pickle_data = pickle.load(f)
        x_data = pickle_data['x_data']
        y_data = pickle_data['y_data']
    print('Data loaded.')
    return x_data, y_data

# %%
data_file = './gdrive/MyDrive/NowMSM/train_data.p'
images, labels = load_data(data_file)

n_samples = labels.shape[0]
print('Total samples:', n_samples)
print('images shape:', images.shape)
print('labels shape:', labels.shape)
# Out:
# Loading data ...
# Data loaded.
# Total samples: 28794
# images shape: (28794, 48, 48)
# labels shape: (28794,)

# %%
print(labels)
# Out:
# ['angry' 'angry' 'angry' ... 'surprise' 'surprise' 'surprise']

# %% [markdown]
# # label preprocessing

# %%
for idx,l_kind in enumerate(labels):
  if l_kind == "angry":
    labels[idx]=0
  elif l_kind == "disgust":
    labels[idx]=1
  elif l_kind == "fear":
    labels[idx]=2
  elif l_kind == "happy":
    labels[idx]=3
  elif l_kind == "neutral":
    labels[idx]=4
  elif l_kind == "sad":
    labels[idx]=5
  elif l_kind == "surprise":
    labels[idx]=6

labels=labels.astype(int)
print(labels)
print(np.unique(labels))
# Out:
# [0 0 0 ... 6 6 6]
# [0 1 2 3 4 5 6]

# %% [markdown]
# # **Explore data**

# %%
emotions = {
    0: 'angry',
    1: 'disgust',
    2: 'fear',
    3: 'happy',
    4: 'neutral',
    5: 'sad',
    6: 'surprise'
}

num_classes = len(emotions)

# %%
def plot_sample_distribution(labels):
    classes, cnts = np.unique(labels, return_counts=True)
    plt.figure(figsize=(12, 5))
    plt.barh(list(emotions.values()), cnts, height=0.6)
    for i, v in enumerate(cnts):
        plt.text(v, i, ' '+str(v), va='center')
    plt.xlabel('Counts')
    plt.title("Distribution of samples")

plot_sample_distribution(labels)

# %%
def show_images(images, labels, col=5):
    n = images.shape[0]
    row = int(np.ceil(n / col))
    fig = plt.figure(figsize=(2*col, 2*row))
    for i in range(n):
        fig.add_subplot(row, col, i+1)
        plt.imshow(images[i], cmap='gray')
        plt.title(emotions[labels[i]])
        plt.xticks([]), plt.yticks([])
    plt.show()

show_images(images[:25], labels[:25])

# %%
def show_one_emotion(images, labels, id, start=0, num=25):
    image_x = images[labels==id]
    label_x = labels[labels==id]
    show_images(image_x[start:start+num], label_x[start:start+num])

show_one_emotion(images, labels, id=0)

# %% [markdown]
# # **Split dataset**

# %%
image_train, image_test, label_train, label_test = train_test_split(images, labels, test_size=0.2, random_state=42)
image_train, image_val, label_train, label_val = train_test_split(image_train, label_train, test_size=0.2, random_state=42)

print('Training samples:', label_train.shape[0])
print('Validation samples:', label_val.shape[0])
print('Test samples:', label_test.shape[0])
# Out:
# Training samples: 18428
# Validation samples: 4607
# Test samples: 5759

# %% [markdown]
# # **Upsamling training data**

# %%
def upsampling(x, y, strategy):
    (n, w, h) = x.shape
    sm = SMOTE(sampling_strategy=strategy, random_state=42)
    x_flat = x.reshape((n,-1))
    x_up, y_up = sm.fit_resample(x_flat, y)
    n_up = x_up.shape[0]
    x_up = x_up.reshape((n_up,w,h))

    return x_up, y_up

# %%
collections.Counter(label_train)
# Out:
# Counter({4: 3214, 2: 2625, 3: 4561, 0: 2567, 6: 2066, 5: 3129, 1: 266})

# %%
image_train_up, label_train_up = upsampling(image_train, label_train, 'auto')

# %%
collections.Counter(label_train_up)
# Out:
# Counter({4: 4561, 2: 4561, 3: 4561, 0: 4561, 6: 4561, 5: 4561, 1: 4561})

# %%
num_classes
# Out:
# 7

# %%
for i in range(num_classes):
    show_one_emotion(image_train_up, label_train_up, id=i, start=4000, num=5)

# %% [markdown]
# # **Utils**

# %%
def one_hot_encoding(labels, num_classes):
    return tf.keras.utils.to_categorical(labels, num_classes)

# %%
def reshape_images(images, channel=1, resize=None):
    x = tf.expand_dims(tf.convert_to_tensor(images), axis=3)
    if channel > 1:
        x = tf.repeat(x, channel, axis=3)
    if resize is not None:
        x = tf.image.resize(x, resize)
    return x

# %%
def pre_processing(images, labels, num_classes, channel=1, resize=None, one_hot=True):
    x = reshape_images(images, channel, resize)
    y = one_hot_encoding(labels, num_classes)
    return x, y

# %%
def plot_metrics(history):
    metrics = ['loss', 'accuracy']
    plt.figure(figsize=(15, 6))
    plt.rc('font', size=12)
    for n, metric in enumerate(metrics):
        name = metric.capitalize()
        plt.subplot(1,2,n+1)
        plt.plot(history.epoch, history.history[metric], label='Training', lw=3, color='navy')
        plt.plot(history.epoch, history.history['val_'+metric], lw=3, label='Validation', color='deeppink')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        plt.title('Model '+name)
        plt.legend()
    plt.show()

# %%
def evaluate_class(model, x_test, y_test):
    labels = np.argmax(y_test, axis=1)
    print('{:<15}Accuracy'.format('Emotion'))
    print('-'*23)
    for i in range(num_classes):
        x = x_test[labels==i]
        y = y_test[labels==i]
        loss, acc = model.evaluate(x,  y, verbose=0)
        print('{:<15}{:.1%}'.format(emotions[i], acc))
    print('-'*23)
    loss, acc = model.evaluate(x_test,  y_test, verbose=0)
    print('{:<15}{:.1%}'.format('Overall', acc))

# %% [markdown]
# # **Model**

# %%
def model_checkpoint_cb(file_path):
    return ModelCheckpoint(
        file_path, monitor='val_accuracy', mode='max',
        save_best_only=True, save_weights_only=True)

# %%
x_train, y_train = pre_processing(image_train_up, label_train_up, num_classes)
x_val, y_val = pre_processing(image_val, label_val, num_classes)
x_test, y_test = pre_processing(image_test, label_test, num_classes)

train_datagen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True)

val_datagen = ImageDataGenerator()

batch_size = 128
train_generator = train_datagen.flow(x_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(x_val, y_val)

steps_per_epoch = train_generator.n // train_generator.batch_size
input_shape = x_train[0].shape

# %%
# one_batch = train_generator.next()
# one_batch_images = one_batch[0].reshape((128,48,48))
# one_batch_labels = np.argmax(one_batch[1], axis=1)
# show_images(one_batch_images[:25], one_batch_labels[:25])

# %%
class VGGNet(Sequential):
    def __init__(self, input_shape, num_classes, checkpoint_path):
        super().__init__()
        self.add(Rescaling(1./255, input_shape=input_shape))
        self.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal'))
        self.add(BatchNormalization())
        self.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
        self.add(BatchNormalization())
        self.add(MaxPool2D())
        self.add(Dropout(0.5))

        self.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
        self.add(BatchNormalization())
        self.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
        self.add(BatchNormalization())
        self.add(MaxPool2D())
        self.add(Dropout(0.4))

        self.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
        self.add(BatchNormalization())
        self.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
        self.add(BatchNormalization())
        self.add(MaxPool2D())
        self.add(Dropout(0.5))

        self.add(Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
        self.add(BatchNormalization())
        self.add(Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))
        self.add(BatchNormalization())
        self.add(MaxPool2D())
        self.add(Dropout(0.4))

        self.add(Flatten())
        
        self.add(Dense(1024, activation='relu'))
        self.add(Dropout(0.5))
        self.add(Dense(256, activation='relu'))

        self.add(Dense(num_classes, activation='softmax'))
        
        self.checkpoint_path = checkpoint_path

# %%
# with strategy.scope():
#   model = VGGNet(input_shape, num_classes, 'run/vggnet_up.h5')
#   model.compile(optimizer=Adam(learning_rate=1e-3),
#                     loss=categorical_crossentropy,
#                     metrics=['accuracy'])
# model.summary()

model = VGGNet(input_shape, num_classes, 'run/vggnet_up.h5')
model.compile(optimizer=Adam(learning_rate=1e-3),
                    loss=categorical_crossentropy,
                    metrics=['accuracy'])
model.summary()
# Out:
# Model: "vgg_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 48, 48, 1)         0
#
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (BatchN  (None, 46, 46, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 23, 23, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 23, 23, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 23, 23, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 256)       295168
#
#  batch_normalization_4 (Batc  (None, 11, 11, 256)      1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 256)       590080
#
#  batch_normalization_5 (Batc  (None, 11, 11, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 256)         0
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 512)         1180160
#
#  batch_normalization_6 (Batc  (None, 5, 5, 512)        2048
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 5, 5, 512)         2359808
#
#  batch_normalization_7 (Batc  (None, 5, 5, 512)        2048
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 7,054,279
# Trainable params: 7,050,439
# Non-trainable params: 3,840
# _________________________________________________________________

# %%
epochs = 100

cp = model_checkpoint_cb(model.checkpoint_path)
lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=1e-10)
es = EarlyStopping(monitor='val_loss', verbose=1, patience=20)

history=model.fit(train_generator,
          steps_per_epoch=steps_per_epoch,
          epochs=epochs,
          validation_data=val_generator,
          callbacks=[lr, es, cp])
# Out:
# Epoch 1/100
# 249/249 [==============================] - 50s 120ms/step - loss: 2.0526 - accuracy: 0.1898 - val_loss: 1.8725 - val_accuracy: 0.2474 - lr: 0.0010
# Epoch 2/100
# 249/249 [==============================] - 28s 114ms/step - loss: 1.8534 - accuracy: 0.2305 - val_loss: 1.8443 - val_accuracy: 0.2520 - lr: 0.0010
# Epoch 3/100
# 249/249 [==============================] - 28s 113ms/step - loss: 1.8244 - accuracy: 0.2511 - val_loss: 1.8024 - val_accuracy: 0.2750 - lr: 0.0010
# Epoch 4/100
# 249/249 [==============================] - 29s 116ms/step - loss: 1.7730 - accuracy: 0.2818 - val_loss: 1.7582 - val_accuracy: 0.2989 - lr: 0.0010
# Epoch 5/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.7001 - accuracy: 0.3242 - val_loss: 1.5635 - val_accuracy: 0.3746 - lr: 0.0010
# Epoch 6/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.6215 - accuracy: 0.3624 - val_loss: 1.4594 - val_accuracy: 0.4443 - lr: 0.0010
# Epoch 7/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.5486 - accuracy: 0.3965 - val_loss: 1.4409 - val_accuracy: 0.4450 - lr: 0.0010
# Epoch 8/100
# 249/249 [==============================] - 28s 110ms/step - loss: 1.4908 - accuracy: 0.4206 - val_loss: 1.4277 - val_accuracy: 0.4432 - lr: 0.0010
# Epoch 9/100
# 249/249 [==============================] - 28s 113ms/step - loss: 1.4474 - accuracy: 0.4417 - val_loss: 1.3298 - val_accuracy: 0.4895 - lr: 0.0010
# Epoch 10/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.4123 - accuracy: 0.4541 - val_loss: 1.2605 - val_accuracy: 0.5049 - lr: 0.0010
# Epoch 11/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.3786 - accuracy: 0.4682 - val_loss: 1.3185 - val_accuracy: 0.4843 - lr: 0.0010
# Epoch 12/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.3504 - accuracy: 0.4809 - val_loss: 1.3056 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 13/100
# 249/249 [==============================] - 29s 116ms/step - loss: 1.3263 - accuracy: 0.4928 - val_loss: 1.2360 - val_accuracy: 0.5311 - lr: 0.0010
# Epoch 14/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.3075 - accuracy: 0.5006 - val_loss: 1.2319 - val_accuracy: 0.5411 - lr: 0.0010
# Epoch 15/100
# 249/249 [==============================] - 27s 110ms/step - loss: 1.2779 - accuracy: 0.5131 - val_loss: 1.3509 - val_accuracy: 0.5107 - lr: 0.0010
# Epoch 16/100
# 249/249 [==============================] - 28s 114ms/step - loss: 1.2616 - accuracy: 0.5225 - val_loss: 1.1548 - val_accuracy: 0.5659 - lr: 0.0010
# Epoch 17/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.2419 - accuracy: 0.5314 - val_loss: 1.2274 - val_accuracy: 0.5418 - lr: 0.0010
# Epoch 18/100
# 249/249 [==============================] - 27s 110ms/step - loss: 1.2244 - accuracy: 0.5411 - val_loss: 1.2266 - val_accuracy: 0.5522 - lr: 0.0010
# Epoch 19/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.2085 - accuracy: 0.5444 - val_loss: 1.1865 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 20/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.1913 - accuracy: 0.5510 - val_loss: 1.1314 - val_accuracy: 0.5798 - lr: 0.0010
# Epoch 21/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.1822 - accuracy: 0.5512 - val_loss: 1.1027 - val_accuracy: 0.5874 - lr: 0.0010
# Epoch 22/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.1659 - accuracy: 0.5626 - val_loss: 1.1129 - val_accuracy: 0.5854 - lr: 0.0010
# Epoch 23/100
# 249/249 [==============================] - 28s 113ms/step - loss: 1.1502 - accuracy: 0.5624 - val_loss: 1.2343 - val_accuracy: 0.5529 - lr: 0.0010
# Epoch 24/100
# 249/249 [==============================] - 28s 110ms/step - loss: 1.1412 - accuracy: 0.5704 - val_loss: 1.0620 - val_accuracy: 0.6039 - lr: 0.0010
# Epoch 25/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.1293 - accuracy: 0.5722 - val_loss: 1.1847 - val_accuracy: 0.5680 - lr: 0.0010
# Epoch 26/100
# 249/249 [==============================] - 28s 112ms/step - loss: 1.1259 - accuracy: 0.5753 - val_loss: 1.1044 - val_accuracy: 0.5856 - lr: 0.0010
# Epoch 27/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.1124 - accuracy: 0.5834 - val_loss: 1.0917 - val_accuracy: 0.5960 - lr: 0.0010
# Epoch 28/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.1021 - accuracy: 0.5862 - val_loss: 1.0956 - val_accuracy: 0.5882 - lr: 0.0010
# Epoch 29/100
# 249/249 [==============================] - ETA: 0s - loss: 1.0907 - accuracy: 0.5898
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 249/249 [==============================] - 27s 109ms/step - loss: 1.0907 - accuracy: 0.5898 - val_loss: 1.1443 - val_accuracy: 0.5754 - lr: 0.0010
# Epoch 30/100
# 249/249 [==============================] - 29s 118ms/step - loss: 1.0569 - accuracy: 0.6004 - val_loss: 1.0798 - val_accuracy: 0.6032 - lr: 5.0000e-04
# Epoch 31/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.0365 - accuracy: 0.6077 - val_loss: 1.0355 - val_accuracy: 0.6089 - lr: 5.0000e-04
# Epoch 32/100
# 249/249 [==============================] - 28s 110ms/step - loss: 1.0215 - accuracy: 0.6119 - val_loss: 1.0743 - val_accuracy: 0.6015 - lr: 5.0000e-04
# Epoch 33/100
# 249/249 [==============================] - 27s 110ms/step - loss: 1.0165 - accuracy: 0.6159 - val_loss: 1.0378 - val_accuracy: 0.6167 - lr: 5.0000e-04
# Epoch 34/100
# 249/249 [==============================] - 27s 110ms/step - loss: 1.0114 - accuracy: 0.6170 - val_loss: 1.0424 - val_accuracy: 0.6132 - lr: 5.0000e-04
# Epoch 35/100
# 249/249 [==============================] - 28s 111ms/step - loss: 1.0065 - accuracy: 0.6214 - val_loss: 1.0045 - val_accuracy: 0.6217 - lr: 5.0000e-04
# Epoch 36/100
# 249/249 [==============================] - 28s 110ms/step - loss: 0.9971 - accuracy: 0.6269 - val_loss: 1.0388 - val_accuracy: 0.6158 - lr: 5.0000e-04
# Epoch 37/100
# 249/249 [==============================] - 28s 110ms/step - loss: 0.9933 - accuracy: 0.6255 - val_loss: 1.0975 - val_accuracy: 0.6019 - lr: 5.0000e-04
# Epoch 38/100
# 249/249 [==============================] - 28s 112ms/step - loss: 0.9856 - accuracy: 0.6294 - val_loss: 0.9892 - val_accuracy: 0.6262 - lr: 5.0000e-04
# Epoch 39/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.9803 - accuracy: 0.6315 - val_loss: 1.0792 - val_accuracy: 0.6106 - lr: 5.0000e-04
# Epoch 40/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.9734 - accuracy: 0.6314 - val_loss: 1.0031 - val_accuracy: 0.6290 - lr: 5.0000e-04
# Epoch 41/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.9675 - accuracy: 0.6351 - val_loss: 1.0236 - val_accuracy: 0.6236 - lr: 5.0000e-04
# Epoch 42/100
# 249/249 [==============================] - 28s 112ms/step - loss: 0.9623 - accuracy: 0.6345 - val_loss: 1.0075 - val_accuracy: 0.6314 - lr: 5.0000e-04
# Epoch 43/100
# 249/249 [==============================] - ETA: 0s - loss: 0.9602 - accuracy: 0.6395
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 249/249 [==============================] - 28s 110ms/step - loss: 0.9602 - accuracy: 0.6395 - val_loss: 1.0208 - val_accuracy: 0.6271 - lr: 5.0000e-04
# Epoch 44/100
# 249/249 [==============================] - 28s 113ms/step - loss: 0.9435 - accuracy: 0.6452 - val_loss: 0.9947 - val_accuracy: 0.6373 - lr: 2.5000e-04
# Epoch 45/100
# 249/249 [==============================] - 27s 110ms/step - loss: 0.9289 - accuracy: 0.6494 - val_loss: 1.0098 - val_accuracy: 0.6306 - lr: 2.5000e-04
# Epoch 46/100
# 249/249 [==============================] - 28s 110ms/step - loss: 0.9231 - accuracy: 0.6531 - val_loss: 1.0260 - val_accuracy: 0.6201 - lr: 2.5000e-04
# Epoch 47/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.9197 - accuracy: 0.6550 - val_loss: 0.9738 - val_accuracy: 0.6421 - lr: 2.5000e-04
# Epoch 48/100
# 249/249 [==============================] - 27s 110ms/step - loss: 0.9193 - accuracy: 0.6532 - val_loss: 0.9880 - val_accuracy: 0.6360 - lr: 2.5000e-04
# Epoch 49/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.9141 - accuracy: 0.6537 - val_loss: 0.9870 - val_accuracy: 0.6382 - lr: 2.5000e-04
# Epoch 50/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.9142 - accuracy: 0.6557 - val_loss: 1.0226 - val_accuracy: 0.6297 - lr: 2.5000e-04
# Epoch 51/100
# 249/249 [==============================] - 27s 110ms/step - loss: 0.9028 - accuracy: 0.6616 - val_loss: 1.0183 - val_accuracy: 0.6360 - lr: 2.5000e-04
# Epoch 52/100
# 249/249 [==============================] - ETA: 0s - loss: 0.9022 - accuracy: 0.6604
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 249/249 [==============================] - 28s 111ms/step - loss: 0.9022 - accuracy: 0.6604 - val_loss: 0.9825 - val_accuracy: 0.6386 - lr: 2.5000e-04
# Epoch 53/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8859 - accuracy: 0.6656 - val_loss: 1.0063 - val_accuracy: 0.6364 - lr: 1.2500e-04
# Epoch 54/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8881 - accuracy: 0.6657 - val_loss: 1.0006 - val_accuracy: 0.6347 - lr: 1.2500e-04
# Epoch 55/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8852 - accuracy: 0.6662 - val_loss: 0.9819 - val_accuracy: 0.6436 - lr: 1.2500e-04
# Epoch 56/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8816 - accuracy: 0.6655 - val_loss: 1.0003 - val_accuracy: 0.6401 - lr: 1.2500e-04
# Epoch 57/100
# 249/249 [==============================] - ETA: 0s - loss: 0.8762 - accuracy: 0.6687
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8762 - accuracy: 0.6687 - val_loss: 0.9969 - val_accuracy: 0.6303 - lr: 1.2500e-04
# Epoch 58/100
# 249/249 [==============================] - 27s 110ms/step - loss: 0.8805 - accuracy: 0.6680 - val_loss: 0.9942 - val_accuracy: 0.6405 - lr: 6.2500e-05
# Epoch 59/100
# 249/249 [==============================] - 28s 114ms/step - loss: 0.8726 - accuracy: 0.6679 - val_loss: 0.9886 - val_accuracy: 0.6382 - lr: 6.2500e-05
# Epoch 60/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8671 - accuracy: 0.6710 - val_loss: 0.9905 - val_accuracy: 0.6399 - lr: 6.2500e-05
# Epoch 61/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8700 - accuracy: 0.6692 - val_loss: 0.9809 - val_accuracy: 0.6418 - lr: 6.2500e-05
# Epoch 62/100
# 249/249 [==============================] - ETA: 0s - loss: 0.8678 - accuracy: 0.6715
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8678 - accuracy: 0.6715 - val_loss: 0.9839 - val_accuracy: 0.6427 - lr: 6.2500e-05
# Epoch 63/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8615 - accuracy: 0.6754 - val_loss: 0.9861 - val_accuracy: 0.6410 - lr: 3.1250e-05
# Epoch 64/100
# 249/249 [==============================] - 28s 111ms/step - loss: 0.8637 - accuracy: 0.6720 - val_loss: 0.9825 - val_accuracy: 0.6438 - lr: 3.1250e-05
# Epoch 65/100
# 249/249 [==============================] - 28s 112ms/step - loss: 0.8637 - accuracy: 0.6753 - val_loss: 0.9853 - val_accuracy: 0.6434 - lr: 3.1250e-05
# Epoch 66/100
# 249/249 [==============================] - 28s 113ms/step - loss: 0.8553 - accuracy: 0.6769 - val_loss: 0.9909 - val_accuracy: 0.6427 - lr: 3.1250e-05
# Epoch 67/100
# 249/249 [==============================] - ETA: 0s - loss: 0.8653 - accuracy: 0.6738
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 249/249 [==============================] - 28s 110ms/step - loss: 0.8653 - accuracy: 0.6738 - val_loss: 0.9934 - val_accuracy: 0.6364 - lr: 3.1250e-05
# Epoch 67: early stopping

# %%
plot_metrics(history)

# %%
model.load_weights(model.checkpoint_path)
evaluate_class(model, x_test, y_test)
# Out:
# Emotion        Accuracy
# -----------------------
# angry          59.2%
# disgust        69.9%
# fear           35.7%
# happy          82.2%
# neutral        72.5%
# sad            45.0%
# surprise       80.6%
# -----------------------
# Overall        63.9%

# %%
# %cp /content/project/run/vggnet.h5 /content/gdrive/MyDrive/loopQ/project/saved_models
